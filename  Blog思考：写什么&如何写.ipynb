# %% [markdown]
# # Blog思考：写什么&如何写
# ---

# %% [markdown]
# ## 1 - 写的目标
# ---
# 写Blog的目标分两类，一类是符合自身发展的系统化目标，称为【通标】；另一类是与Blog内容特性相关的目标，称为【自标】。
#
# ---
# ### 1.1 - 通标
# ---
# * 系统化自身知识体系
# * 表达清晰准确，让读者不需要思考就能明白字里行间表达的是什么
#
# ---
# ### 1.2 - 自标
# ---

# %% [markdown]
# ## 持续发布与集成 -- 系统化写作
# ---
# step 1. 确定一个系统化写作目标，在jupyter中分Cell书写
#
# step 2. 每一个Cell写完了就发布到简书，在明显的位置注明系统化写作目标
